# %% [markdown]
# # GenAI in Non-IT Roles - Introduction
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
# 1. Understand what non_it_roles means and why it matters
# 2. See practical examples of non_it_roles in action
# 3. Know how to apply this concept in your work
# 4. (Technical) Understand the underlying mechanisms
#
# ---

# %% [markdown]
# ## For Everyone: The Big Picture
#
# ### What is GenAI in Non-IT Roles?
#
# How professionals outside of tech are using AI - marketing, HR, education, healthcare, legal, and more.
#
# ### Why Should You Care?
#
# GenAI is democratizing AI capabilities, enabling professionals in all fields to leverage AI.
#
# ### Real-World Examples
#
# Let's look at how this shows up in everyday AI applications:

# %%
# Simple demonstration for everyone
# This code shows non_it_roles in action

print("Welcome to GenAI in Non-IT Roles!")
print()
print("Examples of this concept in action:")
examples = ['Marketing content creation', 'HR screening assistance', 'Educational tutoring', 'Legal document review']
for i, ex in enumerate(examples, 1):
    print(f"  {i}. {ex}")

# %% [markdown]
# ---
#
# ## For Technical Readers: Deeper Dive
#
# ### Technical Overview
#
# Domain-specific applications, workflow integration, prompt templates, and measuring productivity gains.
#
# ### Key Concepts
#
# The following sections dive deeper into the technical aspects of non_it_roles.

# %%
# Technical demonstration
import numpy as np
import matplotlib.pyplot as plt

# Placeholder for concept-specific technical demo
print("Technical demonstration placeholder")
print("See visualization notebook for detailed visualizations")

# %% [markdown]
# ## Reflection Questions
#
# ### For Everyone
# 1. How might you use non_it_roles in your daily work?
# 2. What are potential limitations or risks to be aware of?
#
# ### For Technical Readers
# 1. What are the key trade-offs in implementing non_it_roles?
# 2. How does this concept relate to other parts of the GenAI stack?
#
# ---
#
# ## Next Steps
#
# - Explore the **visualization notebook** for interactive demos
# - Try the **exercises notebook** to practice
# - Open the **HTML demo** for a visual explanation
#
# ### Related Concepts
# - [Prompt Engineering](../07_prompt_engineering/)
# - [Business and Product Use Cases](../15_business_and_product_use_cases/)
