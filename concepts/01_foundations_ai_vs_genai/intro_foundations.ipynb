# %% [markdown]
# # Foundations: AI vs Generative AI - Introduction
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
# 1. Understand what foundations means and why it matters
# 2. See practical examples of foundations in action
# 3. Know how to apply this concept in your work
# 4. (Technical) Understand the underlying mechanisms
#
# ---

# %% [markdown]
# ## For Everyone: The Big Picture
#
# ### What is Foundations: AI vs Generative AI?
#
# Understanding the difference between traditional AI and Generative AI - what makes GenAI special and why everyone is talking about it.
#
# ### Why Should You Care?
#
# GenAI represents a fundamental shift in how we interact with technology. Understanding this foundation helps you make better decisions about when and how to use these tools.
#
# ### Real-World Examples
#
# Let's look at how this shows up in everyday AI applications:

# %%
# Simple demonstration for everyone
# This code shows foundations in action

print("Welcome to Foundations: AI vs Generative AI!")
print()
print("Examples of this concept in action:")
examples = ['ChatGPT writing emails', 'DALL-E creating images', 'GitHub Copilot writing code', 'AI summarizing documents']
for i, ex in enumerate(examples, 1):
    print(f"  {i}. {ex}")

# %% [markdown]
# ---
#
# ## For Technical Readers: Deeper Dive
#
# ### Technical Overview
#
# Distinguishing discriminative vs generative models, understanding the paradigm shift from classification to generation.
#
# ### Key Concepts
#
# The following sections dive deeper into the technical aspects of foundations.

# %%
# Technical demonstration
import numpy as np
import matplotlib.pyplot as plt

# Placeholder for concept-specific technical demo
print("Technical demonstration placeholder")
print("See visualization notebook for detailed visualizations")

# %% [markdown]
# ## Reflection Questions
#
# ### For Everyone
# 1. How might you use foundations in your daily work?
# 2. What are potential limitations or risks to be aware of?
#
# ### For Technical Readers
# 1. What are the key trade-offs in implementing foundations?
# 2. How does this concept relate to other parts of the GenAI stack?
#
# ---
#
# ## Next Steps
#
# - Explore the **visualization notebook** for interactive demos
# - Try the **exercises notebook** to practice
# - Open the **HTML demo** for a visual explanation
#
# ### Related Concepts
# - [Probabilities and Tokens](../02_probabilities_and_tokens/)
# - [Large Language Models (LLMs)](../06_large_language_models/)
