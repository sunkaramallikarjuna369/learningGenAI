# %% [markdown]
# # GenAI in Software Engineering - Exercises
#
# Practice exercises for both non-technical and technical learners.
#
# ## How to Use This Notebook
#
# 1. **Non-IT Professionals**: Focus on the "For Everyone" exercises
# 2. **IT Professionals**: Complete both sections, including coding challenges
# 3. **Solutions**: Available in collapsed cells or at the end
#
# ---

# %% [markdown]
# ## Exercises for Everyone
#
# These exercises focus on understanding and applying software_engineering concepts without coding.
#
# ### Exercise 1: Scenario Analysis
#
# **Scenario**: You are a [role] at a company that wants to use GenAI for [task].
#
# **Questions**:
# 1. How would software_engineering be relevant to this use case?
# 2. What benefits might you expect?
# 3. What risks or limitations should you consider?
#
# *Write your answers in the cell below:*

# %%
# Your answers here (use comments or print statements)
# Exercise 1 Answers:

# 1. Relevance:
# 

# 2. Benefits:
# 

# 3. Risks/Limitations:
#

# %% [markdown]
# ### Exercise 2: Prompt Design
#
# Design 3 different prompts that leverage the concept of software_engineering.
#
# **Context**: You want to [achieve specific goal].
#
# *Write your prompts below:*

# %%
# Your prompts here
prompt_1 = """
[Your first prompt]
"""

prompt_2 = """
[Your second prompt]
"""

prompt_3 = """
[Your third prompt]
"""

print("Prompt 1:", prompt_1)
print("Prompt 2:", prompt_2)
print("Prompt 3:", prompt_3)

# %% [markdown]
# ### Exercise 3: Critical Thinking
#
# Consider the following statement about software_engineering:
#
# > "How developers use AI to write code faster - tools like GitHub Copilot and AI-assisted development."
#
# **Questions**:
# 1. Do you agree with this characterization? Why or why not?
# 2. What's missing from this description?
# 3. How would you explain this to a colleague?
#
# ---

# %% [markdown]
# ## Exercises for Technical Readers
#
# These exercises involve coding and deeper technical understanding.
#
# ### Exercise 4: Implementation Challenge
#
# Implement a simple demonstration of software_engineering.

# %%
# Exercise 4: Implementation
# TODO: Implement a basic version of software_engineering

import numpy as np

def demonstrate_software_engineering(input_data):
    """
    Demonstrate the core concept of software_engineering.
    
    Args:
        input_data: Sample input
    
    Returns:
        Processed output demonstrating the concept
    """
    # Your implementation here
    pass

# Test your implementation
test_input = "sample input"
# result = demonstrate_software_engineering(test_input)
# print(f"Result: {result}")

# %% [markdown]
# ### Exercise 5: Analysis Challenge
#
# Analyze the following code/output and explain what's happening in terms of software_engineering.

# %%
# Analysis exercise
# Given this output, explain the underlying process

sample_output = {
    "input": "Hello, world!",
    "processed": "[PLACEHOLDER]",
    "metrics": {"score": 0.95, "confidence": 0.87}
}

print("Analyze this output:")
print(sample_output)

# Your analysis:
# 1. What does the 'processed' field represent?
# 2. How were the metrics calculated?
# 3. What would change if we modified the input?

# %% [markdown]
# ### Challenge Exercise (Advanced)
#
# **Challenge**: Extend the basic implementation to handle edge cases and optimize performance.
#
# Requirements:
# 1. Handle invalid inputs gracefully
# 2. Add logging/debugging output
# 3. Optimize for [specific metric]
# 4. Write unit tests
#
# ---
#
# ## Solutions
#
# <details>
# <summary>Click to reveal solutions</summary>
#
# ### Exercise 1 Solution
# [Solution explanation]
#
# ### Exercise 4 Solution
# ```python
# # Solution code here
# ```
#
# ### Exercise 5 Solution
# [Analysis explanation]
#
# </details>
#
# ---
#
# ## Summary
#
# You've practiced:
# - Understanding software_engineering conceptually
# - Applying the concept to real scenarios
# - (Technical) Implementing and analyzing software_engineering
#
# **Next Steps**: Explore the HTML demo for an interactive visual explanation!
