# %% [markdown]
# # GenAI in Software Engineering - Introduction
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
# 1. Understand what software_engineering means and why it matters
# 2. See practical examples of software_engineering in action
# 3. Know how to apply this concept in your work
# 4. (Technical) Understand the underlying mechanisms
#
# ---

# %% [markdown]
# ## For Everyone: The Big Picture
#
# ### What is GenAI in Software Engineering?
#
# How developers use AI to write code faster - tools like GitHub Copilot and AI-assisted development.
#
# ### Why Should You Care?
#
# AI is transforming software development, making developers more productive and enabling new workflows.
#
# ### Real-World Examples
#
# Let's look at how this shows up in everyday AI applications:

# %%
# Simple demonstration for everyone
# This code shows software_engineering in action

print("Welcome to GenAI in Software Engineering!")
print()
print("Examples of this concept in action:")
examples = ['GitHub Copilot', 'Cursor IDE', 'AI code review', 'Automated testing', 'Documentation generation']
for i, ex in enumerate(examples, 1):
    print(f"  {i}. {ex}")

# %% [markdown]
# ---
#
# ## For Technical Readers: Deeper Dive
#
# ### Technical Overview
#
# Code generation models, IDE integration, test generation, code review, documentation, and debugging assistance.
#
# ### Key Concepts
#
# The following sections dive deeper into the technical aspects of software_engineering.

# %%
# Technical demonstration
import numpy as np
import matplotlib.pyplot as plt

# Placeholder for concept-specific technical demo
print("Technical demonstration placeholder")
print("See visualization notebook for detailed visualizations")

# %% [markdown]
# ## Reflection Questions
#
# ### For Everyone
# 1. How might you use software_engineering in your daily work?
# 2. What are potential limitations or risks to be aware of?
#
# ### For Technical Readers
# 1. What are the key trade-offs in implementing software_engineering?
# 2. How does this concept relate to other parts of the GenAI stack?
#
# ---
#
# ## Next Steps
#
# - Explore the **visualization notebook** for interactive demos
# - Try the **exercises notebook** to practice
# - Open the **HTML demo** for a visual explanation
#
# ### Related Concepts
# - [Text Generation Use Cases](../08_text_generation_use_cases/)
# - [Agents and Tool Use](../12_agents_and_tool_use/)
